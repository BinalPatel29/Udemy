# %%
## A class is blue print for creating objects, attributes, methods

# %%
class car:
    pass
audi=car()
bmw=car()
print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.car object at 0x7afcc532f0b0>
# <__main__.car object at 0x7afcc532f830>

# %%
audi.windows=4
print(audi.windows)
# Out:
# 4

# %%
tata=car()
tata.doors=4
print(tata.doors)
dir(tata)
# Out:
# 4
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## instance variable and method
class Dog:
    ## constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age
##create an objects
dog1=Dog("buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x7afcc40c07d0>
# buddy
# 3

# %%
dog2=Dog("Lucky",5)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# <__main__.Dog object at 0x7afcc40c1550>
# Lucky
# 5

# %%
## define a method with instance methods
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucky",5)
dog2.bark()
# Out:
# Buddy says woof
# Lucky says woof

# %%
## Modeling a bank account

## define a class for bank account
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance} ")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New balance is { self.balance}")

    def get_balance(self):
        return self.balance

# %%
## create an object
account=BankAccount("Binal",5000)
print(account.balance)
# Out:
# 5000

# %%
## call instance methods
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100

# %%
account.withdraw(300)
# Out:
# 300 is withdrawn. New balance is 4800

# %%
print(account.get_balance())
# Out:
# 4800
