# %%
# Vast collection of modules and packages

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))             ## select random integer
print(random.choice(['apple','banana','cherry']))    ## choise random one in collection of data
# Out:
# 7
# cherry

# %%
## file and directory access
import os
print(os.getcwd())
# Out:
# /workspaces/Udemy/01_besic_pyhon/modules_and_packages

# %%
os.mkdir('test_dir')

# %%
## high level opertions on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization
import json
data={'name':'binal','age':22}

json_str=json.dumps(data)     ## convert into json format  (string)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)    ## for get return back dict
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "binal", "age": 22}
# <class 'str'>
# {'name': 'binal', 'age': 22}
# <class 'dict'>
