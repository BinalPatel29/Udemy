# %%
## also known as dunder methods (doublr underscore methods)
## start and end with double underscores
## enable to define the behavior of objects for inbuilt operations such as arithmetic, comparisons and more

# %%
''' 
__init__
__str__
__repr__
__len__
__getitem__
__setitem__
'''
# Out:
# ' \n__init__\n__str__\n__repr__\n__len__\n__getitem__\n__setitem__\n'

# %%
class Person:
    pass

person=Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)

# %%
## basic methods
class Person:
    def __init__(self,name,age):
       self.name=name
       self.age=age
       
    def __str__(self):
        return f"{self.name},{self.age} years old"
    
    def __repr__(self):
        return f"(name={self.name},age={self.age})"
    
person=Person("Binal",22)
print(person)
print(repr(person))
# Out:
# Binal,22 years old
# (name=Binal,age=22)

# %% [markdown]
# operator overloading

# %%
## common operators overloading magic methods

'''
__add__
__sub__
__mul__
__truediv__
__eq__
__lt__
__gt__
'''
# Out:
# '\n__add__\n__sub__\n__mul__\n__truediv__\n__eq__\n__lt__\n__gt__\n'

# %%
##mathematical operators for vectors
class Vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y

    def __add__(self,other):
        return Vector(self.x+other.x,self.y+other.y)
    
    def __sub__(self,other):
        return Vector(self.x-other.x,self.y-other.y)
    
    def __mul__(self,other):
        return Vector(self.x*other.x,self.y*other.y)
    
    def __eq__(self,other):
        return self.x==other.x and self.y==other.y
    
    def __repr__(self):
        return f"Vector({self.x},{self.y})"
    
## create an objects
v1=Vector(2,3)
v2=Vector(4,5)

print(v1+v2)
print(v1-v2)
print(v1*v2)
print(v1==v2)
# Out:
# Vector(6,8)
# Vector(-2,-2)
# Vector(8,15)
# False

# %%
class ComplexNumber:
    def __init__(self,real,img):
        self.real=real
        self.img=img

    def __add__(self,other):
        return ComplexNumber(self.real+other.real, self.img+other.img)
    
    def __sub__(self,other):
        return ComplexNumber(self.real-other.real, self.img-other.img)
    
    def __mul__(self,other):
        real_part=self.real*other.real - self.img*other.img
        img_part=self.real*other.real + self.img*-other.img
        return ComplexNumber(real_part, img_part)
    
    def __truediv__(self,other):
        denominator= other.real**2 + other.img**2
        real_part=(self.real*other.real + self.img*other.img) / denominator
        img_part=(self.img*other.real - self.real*other.img) / denominator
        return ComplexNumber(real_part, img_part)
    
    def __eq__(self, other):
        return self.real==other.real and self.img==other.img
    
    def __repr__(self):
        return f"{self.real}+{self.img}i"
    
#create an objects
c1=ComplexNumber(2, 3)
c2=ComplexNumber(1, 4)

print(c1+c2)
print(c1-c2)
print(c1*c2)
print(c1/c2)
print(c1==c2)
# Out:
# 3+7i
# 1+-1i
# -10+-10i
# 0.8235294117647058+-0.29411764705882354i
# False

# %% [markdown]
# custom exception(raise and through an exception)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year=int(input("Enter the dob"))   # age=35
age=2025-year

try:
    if age<=30 and age>=20:
        print("The age is valid so you can apply for the exam")

    else:
        raise dobException
    
except dobException:
    print("Sorry, your age should be greater than 20 or less than 30")
# Out:
# Sorry, your age should be greater than 20 or less than 30
