# %%
# exception handling in python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program
# using with try, exxcept, else and finally blocks

## comman exception:
   # ZeroDivisonError: Divide by zero
   # FileNotFoundError: File not found
   # ValueError: Invalid value
   # TypeError: Invalid type

# %%
# exception try, except block
try:
    a=b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
# exception try, except block
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
# Out:
# division by zero
# Please enter the denominator greater than 0

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater than 0")
except Exception as ex1:
    print(ex1)
    print("Main exception get caught here")
# Out:
# name 'b' is not defined
# Main exception get caught here

# %%
try:
    num=int(input('Enter your number'))
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)

# %%
# try, except, else block
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("you can't divide by zero")
except Exception as ex:
    print(ex)
else:
    print(f"The result is '{result}'")
# Out:
# The result is '0.43478260869565216'

# %%
# try, except, else, finally
try:
    num=int(input("Enter a number"))       # if error is not occur than directelly run in else block and if error occur than code stop not run in else block but finally block execute in both condition 
    result=10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("you can't divide by zero")
except Exception as ex:
    print(ex)
else:
    print(f"The result is '{result}'")
finally:
    print("Exection complete")
# Out:
# The result is '0.8333333333333334'
# Exection complete

# %%
# file handling and exception handling
try:
    file=open('example1.txt')
    content=file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("The file doesn't exsists")
except Exception as ex:
    print(ex)

finally:
   if 'file' in locals() or not file.closed:
       file.close()
       print('file close')
# Out:
# name 'b' is not defined
# file close
