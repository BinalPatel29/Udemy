# %%
# it's help organize and reuse the code

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy

# %%
import pandas

# %%
import numpy as np

# %% [markdown]
# 1 in terminal "pip install lib" lib = je lib download karvi hoi ee
#
# 2. import kari levani
#
#
# 3 je python 3.12.1 kernal ma kari levanu aatle thai jashe
#
# 4 terminal ma base envirment hovo pade

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])
