# %% [markdown]
# # for looping and memory allocation

# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(type(my_list))
# Out:
# <class 'list'>

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#iterators
iterator=iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
## iterate through all element
next(iterator)      ##lazy loading
# Out:
# 3

# %%
next(iterator)
# Out:
# 5

# %%
next(iterator)   ## because 5 is last element
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 next(iterator)
#
# StopIteration:

# %%
iterator=iter(my_list)

# %%
try:                            ## after 5 time run the cell o/p below
    print(next(iterator))
except StopIteration:
    print("There are no elements in the iterator")
# Out:
# There are no elements in the iterator

# %%
## string iterator
my_string="Hello"
string_iterator=iter(my_string)

print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
# Out:
# H
# e
# l
# l
# o
